# %% [markdown]
# # Visualizing Multiple Relationships With Facets
#
# **Abid Ali**
#
# Email: [abdsoftfsd@gmail.com](mailto:abdsoftfsd@gmail.com)
#
# Skype: abd.soft

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
automobile_data = pd.read_csv('data/automobiles_data_processed.csv')
automobile_data.head()
# Out:
#    symboling  normalized-losses  make fuel-type aspiration num-of-doors  \
# 0          2                164  audi       gas        std         four
# 1          2                164  audi       gas        std         four
# 2          1                158  audi       gas        std         four
# 3          1                158  audi       gas      turbo         four
# 4          2                192   bmw       gas        std          two
#
#   body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0      sedan          fwd           front        99.8  ...          109
# 1      sedan          4wd           front        99.4  ...          136
# 2      sedan          fwd           front       105.8  ...          136
# 3      sedan          fwd           front       105.8  ...          131
# 4      sedan          rwd           front       101.2  ...          108
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# ...

# %%
automobile_data.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int64
# peak-rpm               int64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
plt.figure(figsize=(15, 10))

fg = sns.FacetGrid(automobile_data,
                   col='fuel-type',
                   height=7, aspect=1)

fg.map(sns.histplot, 'price', color='red', kde=True)
plt.show()

# %%
tips_data = sns.load_dataset('tips')
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(15, 10))

fg = sns.FacetGrid(tips_data,
                   col='size',
                   height=7, aspect=1)

fg.map(sns.histplot, 'total_bill', color='green', kde=True)
plt.show()

# %%
np.sort(tips_data['size'].unique())
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %%
group_size_values = np.sort(tips_data['size'].unique())
plt.figure(figsize=(15, 10))

fg = sns.FacetGrid(tips_data,
                   # row='time',
                   col='time',
                   height=6, aspect=1)

fg.map(sns.swarmplot, 'size', 'total_bill', order=group_size_values)
plt.show()
